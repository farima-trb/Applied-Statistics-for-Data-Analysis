# %% [markdown]
# <a href="https://colab.research.google.com/github/farima-trb/R/blob/main/quiz2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![q1.png](data:image/png;base64,...)

# %%
weight=c(302.2 , 384.8 , 184.4 , 276.3 , 150.7 , 284.5 , 242.8 , 167.1 ,
 232.8 , 197.4 , 207.1 , 226.2 , 246.5 , 238.2 , 269.9 , 215.8 , 283.9 ,
  177.4 , 198.2 , 170.4 , 202.0 , 220.0 , 296.1 , 233.6 , 211.7 , 297.0 ,
   247.0 , 217.5 , 244.1 , 194.8 , 181.2 , 228.7 , 225.8 , 261.5 , 300.7)

range(weight)
# Out:
# [1] 150.7 384.8

# %% [markdown]
# ![q2.png](data:image/png;base64,...)

# %%
low_val  <- 150
high_val <- 385
step_val <- 24
c_breaks <- seq(low_val,high_val,step_val)
x <- cut(weight, c_breaks)
Freq_table <- as.data.frame(table(x))
Freq_table$CumF<-round(Freq_table$Freq,1)/sum(Freq_table$Freq)*100
Freq_table
# Out:
#   x         Freq CumF
# 1 (150,174] 3     8.823529
# 2 (174,198] 5    14.705882
# 3 (198,222] 7    20.588235
# 4 (222,246] 8    23.529412
# 5 (246,270] 4    11.764706
# 6 (270,294] 3     8.823529
# 7 (294,318] 4    11.764706
# 8 (318,342] 0     0.000000
# 9 (342,366] 0     0.000000

# %% [markdown]
# ![q3.png](data:image/png;base64,...)

# %%
cv<-sd(weight)/mean(weight)*100
cv
# Out:
# [1] 20.69831

# %% [markdown]
# ![q5.png](data:image/png;base64,...)

# %%
install.packages("moments")
library(moments)
skewness(weight)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# [1] 0.7594156
